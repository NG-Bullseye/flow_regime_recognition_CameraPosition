# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

# %%
#Create a clustering model
points_n = 200
clusters_n = 3
iteration_n = 100

points = tf.constant(np.random.uniform(0, 10, (points_n, 2)))
centroids = tf.Variable(tf.slice(tf.random.shuffle(points), [0, 0], [clusters_n, -1]))

points_expanded = tf.expand_dims(points, 0)
centroids_expanded = tf.expand_dims(centroids, 1)

distances = tf.reduce_sum(tf.square(tf.subtract(points_expanded, centroids_expanded)), 2)
assignments = tf.argmin(distances, 0)

means = []
for c in range(clusters_n):
    means.append(tf.reduce_mean(
      tf.gather(points,
                tf.reshape(
                  tf.where(
                    tf.equal(assignments, c)
                  ),[1,-1])
               ),[1]))

new_centroids = tf.concat(means, 0)

update_centroids =  tf.compat.v1.assign(centroids, new_centroids)
init = tf.compat.v1.global_variables_initializer()
# Out:
# WARNING:tensorflow:Tensor._shape is private, use Tensor.shape instead. Tensor._shape will eventually be removed.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_48144/1714896472.py in <module>
#       5
#       6 points = tf.constant(np.random.uniform(0, 10, (points_n, 2)))
# ----> 7 centroids = tf.Variable(tf.slice(tf.random.shuffle(points), [0, 0], [clusters_n, -1]))
#       8
#       9 points_expanded = tf.expand_dims(points, 0)
#
# /tmp/ipykernel_48144/1714896472.py in <module>
#       5
#       6 points = tf.constant(np.random.uniform(0, 10, (points_n, 2)))
# ----> 7 centroids = tf.Variable(tf.slice(tf.random.shuffle(points), [0, 0], [clusters_n, -1]))
#       8
#       9 points_expanded = tf.expand_dims(points, 0)
#
# /snap/pycharm-professional/285/plugins/python/helpers/pydev/_pydevd_bundle/pydevd_frame.py in trace_dispatch(self, frame, event, arg)
#     745                 # if thread has a suspend flag, we suspend with a busy wait
#     746                 if info.pydev_state == STATE_SUSPEND:
# --> 747                     self.do_wait_suspend(thread, frame, event, arg)
#     748                     # No need to reset frame.f_trace to keep the same trace function.
#     749                     return self.trace_dispatch
#
# /snap/pycharm-professional/285/plugins/python/helpers/pydev/_pydevd_bundle/pydevd_frame.py in do_wait_suspend(self, *args, **kwargs)
#     142
#     143     def do_wait_suspend(self, *args, **kwargs):
# --> 144         self._args[0].do_wait_suspend(*args, **kwargs)
#     145
#     146     # IFDEF CYTHON
#
# /snap/pycharm-professional/285/plugins/python/helpers/pydev/pydevd.py in do_wait_suspend(self, thread, frame, event, arg, send_suspend_message, is_unhandled_exception)
#    1153
#    1154         with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, stop_reason):
# -> 1155             self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread)
#    1156
#    1157     def _do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread):
#
# /snap/pycharm-professional/285/plugins/python/helpers/pydev/pydevd.py in _do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread)
#    1168
#    1169                 self.process_internal_commands()
# -> 1170                 time.sleep(0.01)
#    1171
#    1172         self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#
# KeyboardInterrupt:

# %%
#Build clusters and display results
#with tf.compat.v1.Session() as sess:
 # sess.run(init)

for step in range(iteration_n):
    [_, centroid_values, points_values, assignment_values] = [update_centroids, centroids, points, assignments]

    print("centroids", centroid_values)

plt.scatter(points_values[:, 0], points_values[:, 1], c=assignment_values, s=50, alpha=0.5)
plt.plot(centroid_values[:, 0], centroid_values[:, 1], 'kx', markersize=15)
plt.show()
# Out:
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
# centroids <tf.Variable 'Variable:0' shape=(3, 2) dtype=float64, numpy=
# array([[9.49496328, 4.88028246],
#        [4.79237431, 3.84436819],
#        [5.55841861, 8.743801  ]])>
